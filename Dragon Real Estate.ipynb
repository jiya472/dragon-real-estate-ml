# %%
import os
print(os.getcwd())
# Out:
# C:\Users\JIYA KUMARI SHARMA\Desktop\ML Project

# %%
import pandas as pd

# Use raw string to avoid escape sequence issues
housing = pd.read_excel(r"C:\Users\JIYA KUMARI SHARMA\Desktop\ML Project\data.csv.xlsx")

# %%
housing.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRAT  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296   15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242   17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242   17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222   18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222   18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   CRIM    506 non-null    float64
#  1   ZN      506 non-null    float64
#  2   INDUS   506 non-null    float64
#  3   CHAS    506 non-null    int64
#  4   NOX     506 non-null    float64
#  5   RM      506 non-null    float64
#  6   AGE     506 non-null    float64
#  7   DIS     506 non-null    float64
#  8   RAD     506 non-null    int64
#  9   TAX     506 non-null    int64
#  10  PTRAT   506 non-null    float64
#  11  B       506 non-null    float64
#  12  LSTAT   506 non-null    float64
#  13  MEDV    506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
housing['CHAS'].value_counts()
# Out:
# CHAS
# 0    471
# 1     35
# Name: count, dtype: int64

# %%
housing.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX       PTRAT           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
housing.hist(bins=50, figsize=(20, 15))
# Out:
# array([[<Axes: title={'center': 'CRIM'}>, <Axes: title={'center': 'ZN'}>,
#         <Axes: title={'center': 'INDUS'}>,
#         <Axes: title={'center': 'CHAS'}>],
#        [<Axes: title={'center': 'NOX'}>, <Axes: title={'center': 'RM'}>,
#         <Axes: title={'center': 'AGE'}>, <Axes: title={'center': 'DIS'}>],
#        [<Axes: title={'center': 'RAD'}>, <Axes: title={'center': 'TAX'}>,
#         <Axes: title={'center': 'PTRAT'}>, <Axes: title={'center': 'B'}>],
#        [<Axes: title={'center': 'LSTAT'}>,
#         <Axes: title={'center': 'MEDV'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
import matplotlib.pyplot as plt

housing.hist(bins=50, figsize=(20, 15))
plt.show()

# %% [markdown]
# ## TRAIN TEST SPLITTING

# %%
import numpy as np
def split_train_test(data, test_ratio):
    shuffled = np.random.premutation(len(data))
    test_set_size = int(len(data) * test_ratio)
    test_indices = shuffled[:test_set_size]
    train_indices = shuffled[test_set_size:]
    return data.iloc[train_indices],data.iloc[test_indices]

# %%
train_set , test_set = split_train_test(housing,0.2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[232], line 1
# ----> 1 train_set , test_set = split_train_test(housing,0.2)
#
# Cell In[230], line 3, in split_train_test(data, test_ratio)
#       2 def split_train_test(data, test_ratio):
# ----> 3     shuffled = np.random.premutation(len(data))
#       4     test_set_size = int(len(data) * test_ratio)
#       5     test_indices = shuffled[:test_set_size]
#
# AttributeError: module 'numpy.random' has no attribute 'premutation'

# %%
def split_train_test(data, test_ratio):
    np.random.seed(42)
    shuffled = np.random.permutation(len(data))  # corrected here
    test_set_size = int(len(data) * test_ratio)
    test_indices = shuffled[:test_set_size]
    train_indices = shuffled[test_set_size:]
    return data.iloc[train_indices], data.iloc[test_indices]

# Now call the function
train_set, test_set = split_train_test(housing, 0.2)

# %%
train_set, test_set = split_train_test(housing, 0.2)

# %%
print(f"Rows in train set: {len(train_set)}\nRows in test set: {len(test_set)}\n")
# Out:
# Rows in train set: 405
# Rows in test set: 101

# %%
from sklearn.model_selection import train_test_split
train_set,test_set = train_test_split(housing,test_size=0.2,random_state=42)
print(f"Rows in train set: {len(train_set)}\nRows in test set: {len(test_set)}\n")
# Out:
# Rows in train set: 404
# Rows in test set: 102

# %%
sampled_housing = housing.sample(n=506, random_state=42)  # mimic Boston size
train_set, test_set = train_test_split(sampled_housing, test_size=0.2, random_state=42)

print(f"Rows in train set: {len(train_set)}\nRows in test set: {len(test_set)}")
# Out:
# Rows in train set: 404
# Rows in test set: 102

# %%
from sklearn.model_selection import StratifiedShuffleSplit
split = StratifiedShuffleSplit(n_splits=1, test_size=0.2,random_state=42)
for train_index,test_index in split.split(housing, housing['CHAS']):
    strat_train_set=housing.loc[train_index]
    strat_train_set=housing.loc[test_index]

# %%
from sklearn.model_selection import StratifiedShuffleSplit
import pandas as pd
import statsmodels.api as sm

# Load dataset
housing = sm.datasets.get_rdataset("Boston", "MASS").data
housing['CHAS'] = housing['chas'].astype(int)  # Use 'CHAS' as stratification column

# Stratified Split
split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)

for train_index, test_index in split.split(housing, housing["CHAS"]):
    strat_train_set = housing.loc[train_index]
    strat_test_set = housing.loc[test_index]

# Output row counts
print(f"Rows in stratified train set: {len(strat_train_set)}")
print(f"Rows in stratified test set: {len(strat_test_set)}")
# Out:
# Rows in stratified train set: 404
# Rows in stratified test set: 102

# %%
strat_test_set
# Out:
#          crim    zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 342   0.02498   0.0   1.89     0  0.518  6.540   59.7  6.2669    1  422
# 379  17.86670   0.0  18.10     0  0.671  6.223  100.0  1.3861   24  666
# 223   0.61470   0.0   6.20     0  0.507  6.618   80.8  3.2721    8  307
# 219   0.11425   0.0  13.89     1  0.550  6.373   92.4  3.3633    5  276
# 48    0.25387   0.0   6.91     0  0.448  5.399   95.3  5.8700    3  233
# ..        ...   ...    ...   ...    ...    ...    ...     ...  ...  ...
# 88    0.05660   0.0   3.41     0  0.489  7.007   86.3  3.4217    2  270
# 466   3.77498   0.0  18.10     0  0.655  5.952   84.7  2.8715   24  666
# 52    0.05360  21.0   5.64     0  0.439  6.511   21.1  6.8147    4  243
# 121   0.07165   0.0  25.65     0  0.581  6.004   84.1  2.1974    2  188
# 218   0.11069   0.0  13.89     1  0.550  5.951   93.8  2.8893    5  276
#
#      ptratio   black  lstat  medv  CHAS
# 342     15.9  389.96   8.65  16.5     0
# ...

# %%
strat_test_set.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  102.000000  102.000000  102.000000  102.000000  102.000000  102.000000
# mean     3.655942   13.450980   10.312255    0.068627    0.541353    6.303353
# std     10.400966   27.503241    6.761154    0.254068    0.111397    0.662996
# min      0.009060    0.000000    0.460000    0.000000    0.385000    4.138000
# 25%      0.057827    0.000000    4.950000    0.000000    0.448000    5.912750
# 50%      0.176150    0.000000    7.760000    0.000000    0.515000    6.176000
# 75%      2.061955    0.000000   18.100000    0.000000    0.612750    6.539500
# max     88.976200   90.000000   27.740000    1.000000    0.871000    8.725000
#
#               age         dis         rad         tax     ptratio       black  \
# count  102.000000  102.000000  102.000000  102.000000  102.000000  102.000000
# mean    66.733333    3.988460    8.813725  391.980392   18.385294  369.670196
# ...

# %%
strat_test_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 102 entries, 342 to 218
# Data columns (total 15 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     102 non-null    float64
#  1   zn       102 non-null    float64
#  2   indus    102 non-null    float64
#  3   chas     102 non-null    int64
#  4   nox      102 non-null    float64
#  5   rm       102 non-null    float64
#  6   age      102 non-null    float64
#  7   dis      102 non-null    float64
#  8   rad      102 non-null    int64
#  9   tax      102 non-null    int64
#  10  ptratio  102 non-null    float64
#  11  black    102 non-null    float64
#  12  lstat    102 non-null    float64
#  13  medv     102 non-null    float64
#  14  CHAS     102 non-null    int32
# dtypes: float64(11), int32(1), int64(3)
# memory usage: 12.4 KB

# %%
strat_test_set['chas'].value_counts()
# Out:
# chas
# 0    95
# 1     7
# Name: count, dtype: int64

# %%
strat_train_set['CHAS'].value_counts()
# Out:
# CHAS
# 0    376
# 1     28
# Name: count, dtype: int64

# %%
#95/7

# %%
housing = strat_train_set.copy()

# %% [markdown]
# ##LOADING OF CORRELATIONS

# %%
corr_matrix = housing.corr()

# %%
#pearson correlation coffecient means if you are increasing something then see wheather the next thing is increasing or decreasing
#1 value means strong positive correlation

# %%
corr_matrix['medv'].sort_values(ascending=False)
# Out:
# medv       1.000000
# rm         0.695360
# zn         0.360445
# black      0.333461
# dis        0.249929
# CHAS       0.175260
# chas       0.175260
# age       -0.376955
# rad       -0.381626
# crim      -0.388305
# nox       -0.427321
# tax       -0.468536
# indus     -0.483725
# ptratio   -0.507787
# lstat     -0.737663
# Name: medv, dtype: float64

# %%
print(housing.columns)
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'black', 'lstat', 'medv', 'CHAS'],
#       dtype='object')

# %%
from pandas.plotting import scatter_matrix
attributes= ["medv" , "rm", "zn", "lstat"]
scatter_matrix(housing[attributes],figsize=(12,8))
plt.show()

# %%
housing.plot(kind="scatter",x="rm",y="medv",alpha=0.8)
plt.show()

# %%
#we use correlation matriox to remove scatter points

# %% [markdown]
# ##Attribute Combinations

# %%
housing["taxrm"]=housing['tax']/housing['rm']

# %%
housing["taxrm"]
# Out:
# 0      45.019011
# 1      37.688834
# 2      33.681280
# 3      31.723350
# 4      31.061984
#          ...
# 501    41.407553
# 502    44.607843
# 503    39.134174
# 504    40.182514
# 505    45.273632
# Name: taxrm, Length: 506, dtype: float64

# %%
housing.head()

# %%
corr_matrix = housing.corr()
corr_matrix['medv'].sort_values(ascending=False)
# Out:
# medv       1.000000
# rm         0.695360
# zn         0.360445
# black      0.333461
# dis        0.249929
# CHAS       0.175260
# chas       0.175260
# age       -0.376955
# rad       -0.381626
# crim      -0.388305
# nox       -0.427321
# tax       -0.468536
# indus     -0.483725
# ptratio   -0.507787
# taxrm     -0.537650
# lstat     -0.737663
# Name: medv, dtype: float64

# %%
housing.plot(kind="scatter",x="taxrm",y="medv",alpha=0.8)
plt.show()

# %%
housing = strat_train_set.drop("medv",axis = 1)
housing_labels = strat_train_set["medv"].copy()

# %% [markdown]
# MISSING ATTRIBUTES

# %%
# To take care of missing attributes , you have three options:
#  1.Get rid from missing datapoints
#  2.Get rid of the whole attributes
#  3.Set the value to some value(0, mean or median)

# %%
a=housing.dropna(subset=["rm"])
a.shape
# Out:
# (404, 14)

# %%
housing.drop("rm",axis=1)
# Out:
#         crim    zn  indus  chas    nox   age     dis  rad  tax  ptratio  \
# 254  0.04819  80.0   3.64     0  0.392  32.0  9.2203    1  315     16.4
# 348  0.01501  80.0   2.01     0  0.435  29.7  8.3440    4  280     17.0
# 476  4.87141   0.0  18.10     0  0.614  93.6  2.3053   24  666     20.2
# 321  0.18159   0.0   7.38     0  0.493  54.3  4.5404    5  287     19.6
# 326  0.30347   0.0   7.38     0  0.493  28.9  5.4159    5  287     19.6
# ..       ...   ...    ...   ...    ...   ...     ...  ...  ...      ...
# 155  3.53501   0.0  19.58     1  0.871  82.6  1.7455    5  403     14.7
# 423  7.05042   0.0  18.10     0  0.614  85.1  2.0218   24  666     20.2
# 98   0.08187   0.0   2.89     0  0.445  36.9  3.4952    2  276     18.0
# 455  4.75237   0.0  18.10     0  0.713  86.5  2.4358   24  666     20.2
# 216  0.04560   0.0  13.89     1  0.550  56.0  3.1121    5  276     16.4
#
#       black  lstat  CHAS
# 254  392.89   6.57     0
# 348  390.94   5.99     0
# ...

# %%
median = housing["rm"].median()
print("Median of rm:", median)
# Out:
# Median of rm: 6.21

# %%
housing["rm"].fillna(median)
#note in every case original dataset is unchanged
# Out:
# 254    6.108
# 348    6.635
# 476    6.484
# 321    6.376
# 326    6.312
#        ...
# 155    6.152
# 423    6.103
# 98     7.820
# 455    6.525
# 216    5.888
# Name: rm, Length: 404, dtype: float64

# %%
housing.shape

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy="median")
housing = housing.select_dtypes(include=["float64", "int64"])
imputer.fit(housing)
# Out:
# SimpleImputer(strategy='median')

# %%
imputer.statistics_
# Out:
# array([2.86735e-01, 0.00000e+00, 9.90000e+00, 0.00000e+00, 5.38000e-01,
#        6.21000e+00, 7.82000e+01, 3.12220e+00, 5.00000e+00, 3.37000e+02,
#        1.90000e+01, 3.90955e+02, 1.15700e+01])

# %%
X = imputer.transform(housing)

# %%
housing_tr=pd.DataFrame(X, columns=housing.columns)

# %%
housing_tr.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean     3.602814   10.836634   11.344950    0.069307    0.558064    6.279908
# std      8.099383   22.150636    6.877817    0.254290    0.116875    0.712983
# min      0.006320    0.000000    0.740000    0.000000    0.389000    3.561000
# 25%      0.086962    0.000000    5.190000    0.000000    0.453000    5.878750
# 50%      0.286735    0.000000    9.900000    0.000000    0.538000    6.210000
# 75%      3.731923   12.500000   18.100000    0.000000    0.631000    6.630250
# max     73.534100  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       black  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean    69.039851    3.746210    9.735149  412.341584   18.473267  353.392822
# ...

# %%
print(housing["rm"].describe())
# Out:
# count    404.000000
# mean       6.279908
# std        0.712983
# min        3.561000
# 25%        5.878750
# 50%        6.210000
# 75%        6.630250
# max        8.780000
# Name: rm, dtype: float64

# %%
print("Total rows in dataset:", len(housing))
# Out:
# Total rows in dataset: 404

# %% [markdown]
# SCIKIT-LEARN DESIGN

# %% [markdown]
# <!-- Primarily , three types of objects
# 1.Estimators - It estimates some parameter based on a dataset.Eg.imputer.
# It has a fit method and transfor method.
# Fit method - Fits the dataset and calculates internal parameters
#
# 2. Transformers- Transform method takes input and returns output based on the learnings from fit(). It also has a convenience fxn called fit_transform() fits and then transforms.
#
# 3. predictors - LinearRegression model is an example of predictor . fit() and predict() are two common fxns. It also gives score() fxn which evaluate the predictions. -->

# %% [markdown]
# ##FEATURE SCALING

# %% [markdown]
# Primarily, two types of feature scaling methods:
# 1.Min-max scaling (Normalization)
#  (value-min)/(max-min)
#  sklearn provides a class called MinMaxScaler for this
# 2.Standarization
#  (value-mean)/std
#  sklearn provides  a class called StandardScaler for this

# %% [markdown]
# ##creating pipeline

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

my_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy="median")),
    ('std_scaler', StandardScaler()),
])

# %%
housing_num_tr = my_pipeline.fit_transform(housing)

# %%
housing_num_tr.shape
# Out:
# (404, 13)

# %% [markdown]
# Selecting a desired model for Dragon Real Estates

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor  # <-- Fix: added 'import'

# model = LinearRegression()
# model = DecisionTreeRegressor()
model = RandomForestRegressor()  # <-- Fix: added parentheses to instantiate the model

model.fit(housing_num_tr, housing_labels)
# Out:
# RandomForestRegressor()

# %%
some_data= housing.iloc[:5]

# %%
some_labels = housing_labels.iloc[:5]

# %%
print(housing_num_tr.shape)  # e.g., (404, 8)
print(housing_labels.shape)  # e.g., (102,)
# Out:
# (404, 13)
# (404,)

# %%
prepared_data=my_pipeline.transform(some_data)

# %%
model.predict(prepared_data)
# Out:
# array([22.438, 25.596, 16.521, 23.387, 23.392])

# %%
list(some_labels)
# Out:
# [21.9, 24.5, 16.7, 23.1, 23.0]

# %% [markdown]
# Evaluating the model

# %%
from sklearn.metrics import mean_squared_error
housing_predictions = model.predict(housing_num_tr)
mse = mean_squared_error(housing_labels, housing_predictions)
rmse = np.sqrt(mse)

# %%
rmse
# Out:
# 1.2099923921698466

# %% [markdown]
# ##Using better evaluation technique-Cross Validation

# %%
from sklearn.model_selection import cross_val_score
import numpy as np

scores = cross_val_score(model, housing_num_tr, housing_labels, scoring="neg_mean_squared_error", cv=10)
rmse_scores = np.sqrt(-scores)

# %%
rmse_scores
# Out:
# array([2.83565453, 2.64288905, 4.44872007, 2.65371942, 3.3250582 ,
#        2.63729379, 4.64081163, 3.30167528, 3.26701829, 3.18610952])

# %%
def print_scores(scores):
    print("Scores:",scores)
    print("Mean:",scores.mean())
    print("Standard deviation:",scores.std())

# %%
print_scores(rmse_scores)
# Out:
# Scores: [2.83565453 2.64288905 4.44872007 2.65371942 3.3250582  2.63729379
#  4.64081163 3.30167528 3.26701829 3.18610952]
# Mean: 3.293894978973808
# Standard deviation: 0.6808759133956432

# %% [markdown]
# Saving the Model

# %%
from joblib import dump , load
dump(model, 'Dragon.joblib')
# Out:
# ['Dragon.joblib']

# %% [markdown]
# ##Testing the model on test data

# %%
X_test = strat_test_set.drop(["medv", "CHAS"], axis=1)
Y_test = strat_test_set["medv"].copy()
X_test_prepared = my_pipeline.transform(X_test)
final_predictions = model.predict(X_test_prepared)
final_mse = mean_squared_error(Y_test, final_predictions)
final_rmse = np.sqrt(final_mse)
print(final_predictions)
# Out:
# [24.915 11.327 25.641 22.356 18.654 15.001 20.04  14.415 31.414 41.219
#  19.954 12.097 23.941 29.739 19.532 10.904 31.581 14.705 23.625 18.831
#  19.745 17.848 17.379 22.08  18.516 30.287 16.337 32.363  9.107 33.44
#  24.068 21.222 23.239 10.846 21.01  11.188 42.939 24.573 23.636 41.516
#  23.779 29.442 20.596 20.841 19.368 33.531 44.514 20.078 20.352 21.916
#  21.162 14.393 21.174 15.005 24.927 32.989 42.576 28.249 19.295 20.964
#  47.491  9.922 18.586 25.1   15.094 33.004 19.803 17.81  18.682 33.777
#  26.793 22.952 21.187 22.748 35.132 12.851 15.762 20.074 21.047 21.569
#  22.223 21.273 14.376 22.708 20.758 21.177 13.894 21.072 21.555 23.169
#  18.696 26.874  7.3   26.281 19.26  29.786 19.753 31.382 14.593 26.66
#  20.962 20.263]

# %%
print("Final RMSE on test set:", final_rmse)
# Out:
# Final RMSE on test set: 2.94170386800895

# %%
prepared_data[0]
# Out:
# array([-0.43942006,  3.12628155, -1.12165014, -0.27288841, -1.42262747,
#        -0.24141041, -1.31238772,  2.61111401, -1.0016859 , -0.5778192 ,
#        -0.97491834,  0.41164221, -0.86091034])

# %% [markdown]
# ##Using the model

# %%
from joblib import dump,load
import numpy as np
model = load('Dragon.joblib')
features= np.array([[-0.43942006,  3.12628155, -1.12165014, -0.27288841, -1.42262747,
       -0.24141041, -1.31238772,  2.61111401, -1.0016859 , -0.5778192 ,
       -0.97491834,  0.41164221, -0.86091034]])
model.predict(features)
# Out:
# array([22.438])
